# %%
#Creamos variables globales de tipo diccionario que contenga los suites, rangos y sus valores respectivos
from random import shuffle
suits = ("Hearts","Clubs","Diamonds","Spades")
ranks =  ("Two","Three","Four","Five","Six","Seven","Eight","Nine","Ten","Jack","Queen","King","Ace")
rank_values = {"Two":2,"Three":3,"Four":4,"Five":5,"Six":6,"Seven":7,"Eight":8,"Nine":9,"Ten":10,"Jack":11,"Queen":12,"King":13,"Ace":14}

# %%
#Definimos la clase Card para crear cada carta
class Card:
    
    def __init__(self,rank,suite):
        self.rank = rank.capitalize()
        self.suite = suite.capitalize()
        self.value = rank_values[rank]
        
    def __str__(self):
        return self.rank +" of "+ self.suite

# %%
#Definis la clase Deck
class Deck:
    
    def __init__(self):
        
        self.all_cards = []
        
        #Creamos las cartas de la baraja
        for suit in suits:
            for rank in ranks:
                created_card = Card(rank,suit)
                self.all_cards.append(created_card)

    def shuffle_deck(self):
        shuffle(self.all_cards)
        
    def deal_one(self):
        return self.all_cards.pop()

# %%
#Definimos la clase Player
class Player:
    
    def __init__(self,name):
        self.name = name
        self.all_cards = []
        
    def remove_one(self):
        return self.all_cards.pop(0)
        
    def add_cards(self,new_cards):
        #Lista de multiples cartas
        if type(new_cards) == type([]):         
            return self.all_cards.extend(new_cards)
        #Para agregar solo una carta
        else:
            return self.all_cards.append(new_cards)
        
    def __str__(self):
        return f"Player {self.name} has {len(self.all_cards)} cards"

# %%
## GAME SETUP
player_one = Player("ONE")
player_two = Player("TWO")

new_deck = Deck()
new_deck.shuffle_deck()

for x in range (26):
    player_one.add_cards(new_deck.deal_one())
    player_two.add_cards(new_deck.deal_one())

# %%
# Out:
# 5

# %%
game_on = True

# %%
round_num = 0

while game_on:
    
    round_num += 1
    print(f"Round {round_num}")
          
    if len(player_one.all_cards) == 0:
          print(f"Player: {player_one.name } out of cards")
          print(f"Player: {player_two.name} wins!")
          game_on = False
          break
          
    elif len(player_two.all_cards) == 0:
          print(f"Player: {player_two.name } out of cards")
          print(f"Player: {player_one.name} wins!")
          game_on = False
          break
          
    #Start a new round
    player_one_cards = []
    player_one_cards.append(player_one.remove_one())
   
    
    player_two_cards = []
    player_two_cards.append(player_two.remove_one())
   
    
    at_war = True
    
    while at_war:
        
        #Jugador 1 gana
        if player_one_cards[-1].value > player_two_cards[-1].value:
            print("Player 1 wins round {}".format(round_num))
            player_one.add_cards(player_one_cards)
            player_one.add_cards(player_two_cards)           
            at_war = False
            
        
        #Jugador 2 gana
        elif player_one_cards[-1].value < player_two_cards[-1].value:            
            print("Player 2 wins round {}".format(round_num))
            player_two.add_cards(player_one_cards)
            player_two.add_cards(player_two_cards)
            at_war = False
        
        #Empate y guerra
        else:
            print("WAR!")
            if (len(player_one.all_cards) < 5):
                print("Player One unable to declare War")
                print("Player Two WINS!")    
                game_on = False
                break
                
            elif (len(player_two.all_cards) < 5):
                print("Player Two unable to declare War")
                print("Player One WINS!")
                game_on = False
                break                
            
            else:
                for deal_cards in range(5):
                    player_one_cards.append(player_one.remove_one())
                    player_two_cards.append(player_two.remove_one())
# Out:
# Round 1
# Player 2 wins round 1
# Round 2
# Player 1 wins round 2
# Round 3
# Player 1 wins round 3
# Round 4
# Player 1 wins round 4
# Round 5
# Player 1 wins round 5
# Round 6
# Player 1 wins round 6
# Round 7
# Player 2 wins round 7
# Round 8
# Player 1 wins round 8
# Round 9
# Player 1 wins round 9
# Round 10
# Player 2 wins round 10
# Round 11
# Player 2 wins round 11
# Round 12
# Player 2 wins round 12
# Round 13
# Player 1 wins round 13
# Round 14
# Player 1 wins round 14
# Round 15
# Player 1 wins round 15
# Round 16
# Player 1 wins round 16
# Round 17
# Player 1 wins round 17
# Round 18
# Player 1 wins round 18
# Round 19
# Player 1 wins round 19
# Round 20
# Player 1 wins round 20
# Round 21
# Player 1 wins round 21
# Round 22
# Player 2 wins round 22
# Round 23
# Player 2 wins round 23
# Round 24
# Player 2 wins round 24
# Round 25
# Player 1 wins round 25
# Round 26
# Player 2 wins round 26
# Round 27
# Player 2 wins round 27
# Round 28
# Player 2 wins round 28
# ...
